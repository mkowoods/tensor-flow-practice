# %%
# %matplotlib inline

# %%
import visualize_misses as vm

# %%
misses = vm.Misses('misses_softmax_nn.json')

# %%
print misses.count
# Out:
# 908

# %%
for i, idx in enumerate(range(25)):
    lbl, guess, img = misses.get_img(idx)
    print i, 'Actual', lbl, 'Prediction', guess
    vm.plot_image(img)
# Out:
# 0 Actual 5 Prediction 6
# 1 Actual 4 Prediction 6
# 2 Actual 2 Prediction 3
# 3 Actual 3 Prediction 2
# 4 Actual 6 Prediction 7
# 5 Actual 9 Prediction 7
# 6 Actual 7 Prediction 9
# 7 Actual 2 Prediction 8
# 8 Actual 7 Prediction 4
# 9 Actual 4 Prediction 8
# 10 Actual 2 Prediction 9
# 11 Actual 9 Prediction 8
# 12 Actual 9 Prediction 3
# 13 Actual 3 Prediction 5
# 14 Actual 6 Prediction 5
# 15 Actual 8 Prediction 7
# 16 Actual 9 Prediction 8
# 17 Actual 3 Prediction 5
# 18 Actual 4 Prediction 6
# 19 Actual 6 Prediction 0
# 20 Actual 8 Prediction 5
# 21 Actual 4 Prediction 6
# 22 Actual 3 Prediction 5
# 23 Actual 2 Prediction 3
# 24 Actual 9 Prediction 7
