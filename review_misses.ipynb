# %%
# %matplotlib inline

# %%
import visualize_misses as vm

# %%
misses = vm.misses

# %%
for idx in range(misses.count):
    lbl, guess, img = misses.get_img(idx)
    print 'Actual', lbl, 'Prediction', guess
    vm.plot_image(img)
# Out:
# Actual 5 Prediction 8
# Actual 6 Prediction 0
# Actual 9 Prediction 4
# Actual 2 Prediction 1
# Actual 9 Prediction 7
# Actual 2 Prediction 7
# Actual 4 Prediction 9
# Actual 4 Prediction 9
# Actual 2 Prediction 7
# Actual 3 Prediction 2
# Actual 2 Prediction 1
# Actual 4 Prediction 9
# Actual 7 Prediction 1
# Actual 8 Prediction 2
# Actual 9 Prediction 4
# Actual 3 Prediction 1
